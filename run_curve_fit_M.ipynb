# %%
! python curve_fit_M.py
# Out:
#   message: The solver successfully reached the end of the integration interval.
#   success: True
#    status: 0
#         t: [ 1.000e+00  2.000e+00 ...  2.680e+02  2.690e+02]
#         y: [[ 8.197e+07  8.197e+07 ...  7.391e+07  7.382e+07]
#             [ 1.650e+04  1.523e+04 ...  4.347e+05  4.370e+05]
#             ...
#             [ 2.641e+03  3.277e+03 ...  5.973e+06  6.043e+06]
#             [ 8.202e+01  1.624e+02 ...  6.093e+05  6.162e+05]]
#       sol: None
#  t_events: None
#  y_events: None
#      nfev: 470
#      njev: 0
#       nlu: 0
#   message: The solver successfully reached the end of the integration interval.
#   success: True
#    status: 0
#         t: [ 1.000e+00  2.000e+00 ...  2.680e+02  2.690e+02]
#         y: [[ 8.197e+07  8.197e+07 ...  7.391e+07  7.382e+07]
#             [ 1.650e+04  1.523e+04 ...  4.347e+05  4.370e+05]
#             ...
#             [ 2.641e+03  3.277e+03 ...  5.973e+06  6.043e+06]
# ...
